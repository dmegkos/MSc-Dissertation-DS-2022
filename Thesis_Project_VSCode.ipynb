# %% [markdown]
# ## Import the libraries

# %%
# For data handling and EDA
import pandas as pd
import numpy as np
# For Visualisation
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import STOPWORDS
# For NLP and ML
#import torch
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay, f1_score
from sklearn.svm import LinearSVC
#import nltk
import spacy
import keras
from keras.preprocessing.text import Tokenizer

# %% [markdown]
# ## Using the whole dataset

# %% [markdown]
# ### Load the whole dataset to Pandas

# %%
# Load the annotations metadata csv to get label info
annot = pd.read_csv("hate-speech-dataset-master/annotations_metadata.csv")
# Keep only file id and label
annot.drop(columns=['user_id','subforum_id','num_contexts'],inplace=True)
# Add new empty column to insert the message
annot['message']=''
# Loop through all lines
for i in range(len(annot['file_id'])):
    # Get current filename
    filename = annot['file_id'][i]
    # Open the file and read the contents
    with open('hate-speech-dataset-master/all_files/' +filename +'.txt') as f:
        contents= f.read()
    f.close()
    # Add contents to the message column
    annot['message'][i]=contents
# Drop file id
annot.drop(columns=['file_id'],inplace=True)

# %% [markdown]
# ### EDA and Pre-Processing

# %%
# DataFrame information
annot.info()

# %%
# Check the classes and their value counts
annot['label'].value_counts()

# %% [markdown]
# Based on the original paper, there are a total of 10944 sentences, 9507 of them are classified as no hate speech, 1196 are classified as hate speech, 168 are related to hate speech but depends on content and 73 are non English sentences, classified as idk/skip. For the purpose of this research, relation and idk/skip classes will be dropped completely in order to make the problem a binary classification.

# %%
# Keep sentences classified only as noHate and hate
cleanPosts = annot[(annot['label'] != 'relation') & (annot['label'] != 'idk/skip')]
# Reset index
cleanPosts=cleanPosts.reset_index(drop=True)

# %%
# First 5 data points
cleanPosts.head(5)

# %%
# Last 5 data points
cleanPosts.tail(5)

# %%
# Update STOPWORDS
stop_words = STOPWORDS.update(["https", "S"])

# %%
# WordCloud for posts classified as hate
wc_hate = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts['message'][cleanPosts['label']=='hate']))
# Generate plot
plt.imshow(wc_hate)
plt.axis("off")
plt.show()

# %%
# WordCloud for posts classified as noHate
wc_noHate = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts['message'][cleanPosts['label']=='noHate']))
# Generate plot
plt.imshow(wc_noHate)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Recreating Paper Results

# %% [markdown]
# #### Pre-Process text with SpaCy

# %% [markdown]
# Before I proceed with the Bag of Words model, I need to pre-process the text (remove punctuations, stop words, lemmatize) in order to reduce the vocabulary size. I will use SpaCy for text pre-processing.

# %%
# Get English words from NLTK
#nltk.download('words')
#words = set(nltk.corpus.words.words())
# Instantiate SpaCy's English module
nlp = spacy.load('en_core_web_sm')
# Remove default stop words and lemmatize each sentence
cleanPosts['clean_message'] = cleanPosts.message.apply(
    lambda text: 
        " ".join(
            token.lemma_.lower() for token in nlp(text)
                if token.lemma_.lower() not in nlp.Defaults.stop_words and token.is_alpha
                 #and token.lemma_.lower() in words
        )
)
# Drop old sentences
cleanPosts.drop(columns='message', inplace=True)

# %%
# First 5 data points
cleanPosts.head(5)

# %%
# Last 5 data points
cleanPosts.tail(5)

# %%
# Check for empty strings and remove
cleanPosts[cleanPosts['clean_message'] == ''].count()

# %% [markdown]
# There are 233 empty entries after lemmatization and removing stop words, which I am going to remove.

# %%
# Drop rows where 'clean_message' is an empty string
# Get index
idx = cleanPosts[cleanPosts['clean_message'] == ''].index
# Drop rows based on index
cleanPosts.drop(index=idx, inplace=True)

# %%
# WordCloud for cleaned posts classified as hate
wc_hate_clean = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts['clean_message'][cleanPosts['label']=='hate']))
# Generate plot
plt.imshow(wc_hate_clean)
plt.axis("off")
plt.show()

# %%
# WordCloud for cleaned posts classified as noHate
wc_noHate_clean = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts['clean_message'][cleanPosts['label']=='noHate']))
# Generate plot
plt.imshow(wc_noHate_clean)
plt.axis("off")
plt.show()

# %%
# Plot the class distribution
plot = cleanPosts.label.value_counts().plot(kind='pie',autopct='%1.2f%%')

# %% [markdown]
# #### Bag-of-Words Vectors

# %%
# Instantiate Count Vectorizer
vectorizer = CountVectorizer()
# Vectorize
X = vectorizer.fit_transform(cleanPosts.clean_message.to_list())
X_bow = pd.DataFrame(X.toarray(),columns=vectorizer.get_feature_names_out())

# %% [markdown]
# #### Split Dataset for SVM Model

# %%
# Split dataset for training and testing
X_train, X_test, y_train, y_test = train_test_split(X_bow, cleanPosts.label, test_size=0.25, random_state=42, stratify=cleanPosts.label)

# %% [markdown]
# #### Classify text using SVM Model

# %% [markdown]
# Train the SVM Model

# %%
# Instatiate SVC
svm = LinearSVC()
# Fit training data
svm.fit(X_train, y_train)
# Get prediction on test data
pred = svm.predict(X_test)

# %% [markdown]
# #### Get Accuracy and Confusion Matrix

# %%
# Get the accuracy
print('Test Accuracy: '+str(svm.score(X_test, y_test)))
# Print the F1 Score
print('F1 Score: '+str(f1_score(y_test, pred, pos_label='hate')))
# Create confusion matrix
cm = confusion_matrix(y_test, pred, labels=svm.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svm.classes_)
disp.plot()
plt.show()

# %% [markdown]
# Using all the available txt files with text pre-processing on a SVM Model returned an accuracy of 0.87 but an F1 Score of 0.48. This is because there is a big class inbalance in the training data. The SVM model does a really good job at classifying correctly the noHate sentences but handles poorly the hate sentences since more than half of them are missclassified.

# %% [markdown]
# ## Using the sampled train and test dataset

# %% [markdown]
# ### Load the provided sampled_train and sampled_test dataset

# %%
# Sampled Training Data
# Load the annotations metadata csv to get label info
annot_tr = pd.read_csv("hate-speech-dataset-master/annotations_metadata.csv")
# Keep only file id and label
annot_tr.drop(columns=['user_id','subforum_id','num_contexts'],inplace=True)
# Add new empty column to insert the message
annot_tr['message']=''
# Loop through all lines
for i in range(len(annot_tr['file_id'])):
    # Get current filename
    filename = annot_tr['file_id'][i]
    try:
        # Open the file and read the contents
        with open('hate-speech-dataset-master/sampled_train/' +filename +'.txt') as f:
            contents= f.read()
        f.close()
        # Add contents to the message column
        annot_tr['message'][i]=contents
    except:
        print('File '+str(filename)+' not in train samples.')
# Drop file id
annot_tr.drop(columns=['file_id'],inplace=True)

# Sampled Test Data
# Load the annotations metadata csv to get label info
annot_ts = pd.read_csv("hate-speech-dataset-master/annotations_metadata.csv")
# Keep only file id and label
annot_ts.drop(columns=['user_id','subforum_id','num_contexts'],inplace=True)
# Add new empty column to insert the message
annot_ts['message']=''
# Loop through all lines
for i in range(len(annot_ts['file_id'])):
    # Get current filename
    filename = annot_ts['file_id'][i]
    try:
        # Open the file and read the contents
        with open('hate-speech-dataset-master/sampled_test/' +filename +'.txt') as f:
            contents= f.read()
        f.close()
        # Add contents to the message column
        annot_ts['message'][i]=contents
    except:
        print('File '+str(filename)+' not in test samples.')
# Drop file id
annot_ts.drop(columns=['file_id'],inplace=True)
# Out:
# File 12834217_1 not in train samples.
# File 12834217_3 not in train samples.
# File 12834217_5 not in train samples.
# File 12834217_6 not in train samples.
# File 12834217_7 not in train samples.
# File 12834217_8 not in train samples.
# File 12834217_9 not in train samples.
# File 12834217_10 not in train samples.
# File 12843221_1 not in train samples.
# File 12843221_2 not in train samples.
# File 12845600_1 not in train samples.
# File 12845600_2 not in train samples.
# File 12845600_3 not in train samples.
# File 12845600_4 not in train samples.
# File 12845808_1 not in train samples.
# File 12845808_2 not in train samples.
# File 12849464_1 not in train samples.
# File 12849464_3 not in train samples.
# File 12849464_4 not in train samples.
# File 12851329_1 not in train samples.
# File 12851329_2 not in train samples.
# File 12851329_3 not in train samples.
# File 12854837_1 not in train samples.
# File 12854837_2 not in train samples.
# File 12854837_3 not in train samples.
# File 12854837_4 not in train samples.
# File 12855349_1 not in train samples.
# File 12855349_2 not in train samples.
# File 12855497_1 not in train samples.
# File 12855497_2 not in train samples.
# File 12855497_3 not in train samples.
# File 12855806_1 not in train samples.
# File 12855806_2 not in train samples.
# File 12856993_1 not in train samples.
# File 12856993_2 not in train samples.
# File 12858701_1 not in train samples.
# File 12863641_1 not in train samples.
# File 12869018_1 not in train samples.
# File 12869018_2 not in train samples.
# File 12869757_1 not in train samples.
# File 12870229_1 not in train samples.
# File 12870229_2 not in train samples.
# File 12870229_4 not in train samples.
# File 12870229_5 not in train samples.
# File 12870229_6 not in train samples.
# File 12875264_1 not in train samples.
# File 12875264_2 not in train samples.
# File 12875264_3 not in train samples.
# File 12875264_4 not in train samples.
# File 12875264_5 not in train samples.
# File 12883101_3 not in train samples.
# File 12904919_2 not in train samples.
# File 12905790_1 not in train samples.
# File 12905790_2 not in train samples.
# File 12915702_2 not in train samples.
# File 12915702_3 not in train samples.
# File 12915702_4 not in train samples.
# File 13061184_3 not in train samples.
# File 13063006_1 not in train samples.
# File 13063006_2 not in train samples.
# File 13063290_1 not in train samples.
# File 13063290_3 not in train samples.
# File 13119410_1 not in train samples.
# File 13139571_2 not in train samples.
# File 13177001_1 not in train samples.
# File 13177001_2 not in train samples.
# File 13177001_3 not in train samples.
# File 13177001_5 not in train samples.
# File 13209219_2 not in train samples.
# File 13209219_3 not in train samples.
# File 13209219_4 not in train samples.
# File 13271390_1 not in train samples.
# File 13271390_2 not in train samples.
# File 13288494_1 not in train samples.
# File 13288494_2 not in train samples.
# File 13288494_3 not in train samples.
# File 13288494_4 not in train samples.
# File 13288494_5 not in train samples.
# File 13288494_6 not in train samples.
# File 13288494_7 not in train samples.
# File 13288494_8 not in train samples.
# File 13288494_9 not in train samples.
# File 13288494_10 not in train samples.
# File 13288494_11 not in train samples.
# File 13293414_1 not in train samples.
# File 13293414_2 not in train samples.
# File 13293414_3 not in train samples.
# File 13341044_1 not in train samples.
# File 13401474_1 not in train samples.
# File 13406897_1 not in train samples.
# File 13406897_4 not in train samples.
# File 13434590_1 not in train samples.
# File 13435201_1 not in train samples.
# File 13435201_2 not in train samples.
# File 13435201_3 not in train samples.
# File 13442727_1 not in train samples.
# File 13442727_2 not in train samples.
# File 13444199_2 not in train samples.
# File 13446781_1 not in train samples.
# File 13446781_2 not in train samples.
# File 13446781_4 not in train samples.
# File 13446781_5 not in train samples.
# File 13449383_1 not in train samples.
# File 13451430_1 not in train samples.
# File 13451430_2 not in train samples.
# File 13453511_1 not in train samples.
# File 13453511_2 not in train samples.
# File 13454668_2 not in train samples.
# File 13456696_2 not in train samples.
# File 13456696_3 not in train samples.
# File 13456696_4 not in train samples.
# File 13456696_5 not in train samples.
# File 13456696_6 not in train samples.
# File 13456696_7 not in train samples.
# File 13456696_9 not in train samples.
# File 13456696_10 not in train samples.
# File 13456921_2 not in train samples.
# File 13458373_1 not in train samples.
# File 13458373_2 not in train samples.
# File 13458484_1 not in train samples.
# File 13458484_2 not in train samples.
# File 13460017_1 not in train samples.
# File 13461061_1 not in train samples.
# File 13461061_2 not in train samples.
# File 13461719_1 not in train samples.
# File 13461719_3 not in train samples.
# File 13462533_1 not in train samples.
# File 13462533_3 not in train samples.
# File 13463371_1 not in train samples.
# File 13463371_2 not in train samples.
# File 13463371_3 not in train samples.
# File 13467569_1 not in train samples.
# File 13467569_2 not in train samples.
# File 13469056_1 not in train samples.
# File 13473137_1 not in train samples.
# File 13473137_2 not in train samples.
# File 13473465_1 not in train samples.
# File 13474879_1 not in train samples.
# File 13475102_1 not in train samples.
# File 13477084_1 not in train samples.
# File 13477084_2 not in train samples.
# File 13477295_1 not in train samples.
# File 13477295_2 not in train samples.
# File 13477865_2 not in train samples.
# File 13480997_3 not in train samples.
# File 13482637_1 not in train samples.
# File 13482637_2 not in train samples.
# File 13483810_1 not in train samples.
# File 13483810_2 not in train samples.
# File 13484158_1 not in train samples.
# File 13484158_3 not in train samples.
# File 13488146_1 not in train samples.
# File 13488914_1 not in train samples.
# File 13491591_2 not in train samples.
# File 13491591_3 not in train samples.
# File 13491591_4 not in train samples.
# File 13491591_5 not in train samples.
# File 13492064_1 not in train samples.
# File 13492064_3 not in train samples.
# File 13493681_1 not in train samples.
# File 13493681_2 not in train samples.
# File 13494395_1 not in train samples.
# File 13494421_1 not in train samples.
# File 13494421_2 not in train samples.
# File 13494421_3 not in train samples.
# File 13494421_4 not in train samples.
# File 13494421_5 not in train samples.
# File 13494421_6 not in train samples.
# File 13496564_1 not in train samples.
# File 13496564_2 not in train samples.
# File 13496564_3 not in train samples.
# File 13499007_1 not in train samples.
# File 13499007_4 not in train samples.
# File 13499982_1 not in train samples.
# File 13501262_1 not in train samples.
# File 13501262_2 not in train samples.
# File 13501262_3 not in train samples.
# File 13501638_1 not in train samples.
# File 13501638_2 not in train samples.
# File 13503127_1 not in train samples.
# File 13503127_2 not in train samples.
# File 13503127_3 not in train samples.
# File 13503555_2 not in train samples.
# File 13504442_1 not in train samples.
# File 13504529_1 not in train samples.
# File 13504529_2 not in train samples.
# File 13508272_1 not in train samples.
# File 13547398_1 not in train samples.
# File 13547398_3 not in train samples.
# File 13555448_1 not in train samples.
# File 13555448_2 not in train samples.
# File 13561998_1 not in train samples.
# File 13561998_2 not in train samples.
# File 13591603_1 not in train samples.
# File 13591603_2 not in train samples.
# File 13592269_1 not in train samples.
# File 13592269_2 not in train samples.
# File 13592661_1 not in train samples.
# File 13597435_1 not in train samples.
# File 13597435_2 not in train samples.
# File 13597435_4 not in train samples.
# File 13597435_5 not in train samples.
# File 13597435_6 not in train samples.
# File 13597654_1 not in train samples.
# File 13599267_1 not in train samples.
# File 13599267_2 not in train samples.
# File 13600193_1 not in train samples.
# File 13604801_1 not in train samples.
# File 13604948_2 not in train samples.
# File 13604948_3 not in train samples.
# File 13604958_1 not in train samples.
# File 13604958_2 not in train samples.
# File 13605248_1 not in train samples.
# File 13605248_2 not in train samples.
# File 13605248_3 not in train samples.
# File 13605248_4 not in train samples.
# File 13605248_5 not in train samples.
# File 13605248_7 not in train samples.
# File 13605248_8 not in train samples.
# File 13605248_9 not in train samples.
# File 13605248_10 not in train samples.
# File 13605248_11 not in train samples.
# File 13607337_1 not in train samples.
# File 13607337_2 not in train samples.
# File 13609323_1 not in train samples.
# File 13610248_1 not in train samples.
# File 13610248_2 not in train samples.
# File 13611752_1 not in train samples.
# File 13611752_2 not in train samples.
# File 13613228_1 not in train samples.
# File 13615431_1 not in train samples.
# File 13615431_2 not in train samples.
# File 13617074_1 not in train samples.
# File 13646605_1 not in train samples.
# File 13646605_2 not in train samples.
# File 13646605_3 not in train samples.
# File 13843249_2 not in train samples.
# File 13844316_1 not in train samples.
# File 13844316_2 not in train samples.
# File 13844546_1 not in train samples.
# File 13844546_2 not in train samples.
# File 13845891_1 not in train samples.
# File 13846521_2 not in train samples.
# File 13848611_1 not in train samples.
# File 13849471_1 not in train samples.
# File 13850804_1 not in train samples.
# File 13851581_1 not in train samples.
# File 13852217_1 not in train samples.
# File 13855496_2 not in train samples.
# File 13856416_1 not in train samples.
# File 13856416_2 not in train samples.
# File 13857216_1 not in train samples.
# File 13857781_1 not in train samples.
# File 13858923_1 not in train samples.
# File 13858971_1 not in train samples.
# File 13861429_1 not in train samples.
# File 13862105_1 not in train samples.
# File 13862105_2 not in train samples.
# File 13862381_1 not in train samples.
# File 13862956_1 not in train samples.
# File 13863356_2 not in train samples.
# File 13864025_1 not in train samples.
# File 13864288_1 not in train samples.
# File 13864288_2 not in train samples.
# File 13864766_2 not in train samples.
# File 13864766_3 not in train samples.
# File 13864766_4 not in train samples.
# File 13864766_5 not in train samples.
# File 13864827_1 not in train samples.
# File 13865807_1 not in train samples.
# File 13865807_2 not in train samples.
# File 13866457_1 not in train samples.
# File 13866706_1 not in train samples.
# File 13866706_2 not in train samples.
# File 13867797_1 not in train samples.
# File 13867797_2 not in train samples.
# File 13867797_3 not in train samples.
# File 13867797_4 not in train samples.
# File 13939030_1 not in train samples.
# File 13946979_1 not in train samples.
# File 13946979_2 not in train samples.
# File 13947162_1 not in train samples.
# File 13948134_1 not in train samples.
# File 14014191_1 not in train samples.
# File 14017079_1 not in train samples.
# File 14017079_2 not in train samples.
# File 14017079_3 not in train samples.
# File 14017079_4 not in train samples.
# File 14023594_1 not in train samples.
# File 14023594_2 not in train samples.
# File 14023594_3 not in train samples.
# File 14025491_1 not in train samples.
# File 14025960_2 not in train samples.
# File 14025960_4 not in train samples.
# File 14026374_1 not in train samples.
# File 14026466_1 not in train samples.
# File 14026466_3 not in train samples.
# File 14026796_1 not in train samples.
# File 14026796_2 not in train samples.
# File 14026837_1 not in train samples.
# File 14026837_2 not in train samples.
# File 14027650_1 not in train samples.
# File 14027650_2 not in train samples.
# File 14027653_1 not in train samples.
# File 14027653_2 not in train samples.
# File 14027939_1 not in train samples.
# File 14027939_2 not in train samples.
# File 14028809_1 not in train samples.
# File 14028809_2 not in train samples.
# File 14029017_1 not in train samples.
# File 14029332_1 not in train samples.
# File 14030336_1 not in train samples.
# File 14030336_2 not in train samples.
# File 14030845_1 not in train samples.
# File 14031472_1 not in train samples.
# File 14032608_1 not in train samples.
# File 14032740_3 not in train samples.
# File 14032740_4 not in train samples.
# File 14032740_5 not in train samples.
# File 14032740_6 not in train samples.
# File 14032740_7 not in train samples.
# File 14032740_8 not in train samples.
# File 14032740_11 not in train samples.
# File 14032740_12 not in train samples.
# File 14032740_13 not in train samples.
# File 14032740_14 not in train samples.
# File 14034435_1 not in train samples.
# File 14034435_2 not in train samples.
# File 14034808_2 not in train samples.
# File 14034808_3 not in train samples.
# File 14036242_1 not in train samples.
# File 14036285_1 not in train samples.
# File 14037646_1 not in train samples.
# File 14037646_2 not in train samples.
# File 14037646_3 not in train samples.
# File 14037748_1 not in train samples.
# File 14037748_2 not in train samples.
# File 14037748_3 not in train samples.
# File 14038016_1 not in train samples.
# File 14038806_1 not in train samples.
# File 14038806_2 not in train samples.
# File 14038806_3 not in train samples.
# File 14039462_1 not in train samples.
# File 14039553_1 not in train samples.
# File 14039676_2 not in train samples.
# File 14039676_3 not in train samples.
# File 14039896_2 not in train samples.
# File 14039896_3 not in train samples.
# File 14040028_1 not in train samples.
# File 14050951_1 not in train samples.
# File 14051532_1 not in train samples.
# File 14051532_2 not in train samples.
# File 14051600_1 not in train samples.
# File 14051600_2 not in train samples.
# File 14059454_1 not in train samples.
# File 14059454_2 not in train samples.
# File 14059454_3 not in train samples.
# File 14059454_4 not in train samples.
# File 14060302_1 not in train samples.
# File 14062360_1 not in train samples.
# File 14062360_2 not in train samples.
# File 14062890_1 not in train samples.
# File 14063024_1 not in train samples.
# File 14064196_1 not in train samples.
# File 14064480_1 not in train samples.
# File 14064480_2 not in train samples.
# File 14064480_3 not in train samples.
# File 14064480_5 not in train samples.
# File 14064480_6 not in train samples.
# File 14066071_1 not in train samples.
# File 14068441_2 not in train samples.
# File 14068441_3 not in train samples.
# File 14068441_4 not in train samples.
# File 14068441_5 not in train samples.
# File 14068441_6 not in train samples.
# File 14068441_7 not in train samples.
# File 14070612_1 not in train samples.
# File 14073643_1 not in train samples.
# File 14073744_1 not in train samples.
# File 14074039_2 not in train samples.
# File 14078628_1 not in train samples.
# File 14078628_2 not in train samples.
# File 14078800_1 not in train samples.
# File 14078800_2 not in train samples.
# File 14080098_1 not in train samples.
# File 14080098_2 not in train samples.
# File 14080098_3 not in train samples.
# File 14080747_3 not in train samples.
# File 14081935_1 not in train samples.
# File 14081935_2 not in train samples.
# File 14081935_3 not in train samples.
# File 14081935_4 not in train samples.
# File 14083587_1 not in train samples.
# File 14083587_2 not in train samples.
# File 14083587_3 not in train samples.
# File 14088710_1 not in train samples.
# File 14091425_1 not in train samples.
# File 14093901_1 not in train samples.
# File 14093987_1 not in train samples.
# File 14093987_2 not in train samples.
# File 14093987_3 not in train samples.
# File 14094053_1 not in train samples.
# File 14094053_2 not in train samples.
# File 14094053_3 not in train samples.
# File 14094053_4 not in train samples.
# File 14096566_1 not in train samples.
# File 14096566_2 not in train samples.
# File 14098049_2 not in train samples.
# File 14098284_1 not in train samples.
# File 14099272_2 not in train samples.
# File 14099414_1 not in train samples.
# File 14099414_2 not in train samples.
# File 14099414_3 not in train samples.
# File 14099981_1 not in train samples.
# File 14100180_1 not in train samples.
# File 14100290_2 not in train samples.
# File 14100290_3 not in train samples.
# File 14100782_1 not in train samples.
# File 14100820_1 not in train samples.
# File 14102350_1 not in train samples.
# File 14102350_2 not in train samples.
# File 14103292_1 not in train samples.
# File 14103292_3 not in train samples.
# File 14104444_1 not in train samples.
# File 14104444_2 not in train samples.
# File 14104444_3 not in train samples.
# File 14104444_4 not in train samples.
# File 14105266_1 not in train samples.
# File 14105266_2 not in train samples.
# File 14105266_3 not in train samples.
# File 14105266_4 not in train samples.
# File 14106131_1 not in train samples.
# File 14106678_1 not in train samples.
# File 14106678_2 not in train samples.
# File 14108167_1 not in train samples.
# File 14108390_1 not in train samples.
# File 14109043_1 not in train samples.
# File 14109043_2 not in train samples.
# File 14109043_3 not in train samples.
# File 14110686_1 not in train samples.
# File 14110686_2 not in train samples.
# File 14110686_3 not in train samples.
# File 14110686_4 not in train samples.
# File 14110686_6 not in train samples.
# File 14110686_7 not in train samples.
# File 14110686_8 not in train samples.
# File 14110686_9 not in train samples.
# File 14110686_10 not in train samples.
# File 14110686_11 not in train samples.
# File 14110686_12 not in train samples.
# File 14110790_2 not in train samples.
# File 14110886_1 not in train samples.
# File 14110886_2 not in train samples.
# File 14110886_3 not in train samples.
# File 14112030_1 not in train samples.
# File 14112231_1 not in train samples.
# File 14112540_1 not in train samples.
# File 14113349_1 not in train samples.
# File 14113363_1 not in train samples.
# File 14113363_2 not in train samples.
# File 14263949_1 not in train samples.
# File 14264832_1 not in train samples.
# File 14268777_1 not in train samples.
# File 14268777_2 not in train samples.
# File 14268777_3 not in train samples.
# File 14271693_1 not in train samples.
# File 14280425_1 not in train samples.
# File 14287665_1 not in train samples.
# File 14287665_2 not in train samples.
# File 14289836_1 not in train samples.
# File 14289836_2 not in train samples.
# File 14296180_1 not in train samples.
# File 14296825_1 not in train samples.
# File 14296825_2 not in train samples.
# File 14296825_3 not in train samples.
# File 14297280_1 not in train samples.
# File 14297717_1 not in train samples.
# File 14297717_2 not in train samples.
# File 14297717_3 not in train samples.
# File 14297717_4 not in train samples.
# File 14297717_5 not in train samples.
# File 14297717_6 not in train samples.
# File 14297717_7 not in train samples.
# File 14297717_8 not in train samples.
# File 14297717_9 not in train samples.
# File 14297717_10 not in train samples.
# File 14297717_11 not in train samples.
# File 14298104_1 not in train samples.
# File 14298104_2 not in train samples.
# File 14298778_1 not in train samples.
# File 14298778_2 not in train samples.
# File 14299125_1 not in train samples.
# File 14299125_2 not in train samples.
# File 14299125_3 not in train samples.
# File 14299125_4 not in train samples.
# File 14299696_1 not in train samples.
# File 14299818_2 not in train samples.
# File 14299858_1 not in train samples.
# File 14299858_2 not in train samples.
# File 14301403_1 not in train samples.
# File 14301403_2 not in train samples.
# File 14302523_1 not in train samples.
# File 14302523_2 not in train samples.
# File 14302523_3 not in train samples.
# File 14302523_4 not in train samples.
# File 14302559_1 not in train samples.
# File 14302559_2 not in train samples.
# File 14302621_1 not in train samples.
# File 14302621_2 not in train samples.
# File 14302621_3 not in train samples.
# File 14406608_1 not in train samples.
# File 14406608_2 not in train samples.
# File 14406608_3 not in train samples.
# File 14406608_4 not in train samples.
# File 14406608_5 not in train samples.
# File 14407968_1 not in train samples.
# File 14408760_1 not in train samples.
# File 14409265_1 not in train samples.
# File 14409265_3 not in train samples.
# File 14413233_1 not in train samples.
# File 14413563_1 not in train samples.
# File 14413563_2 not in train samples.
# File 14413967_1 not in train samples.
# File 14414144_1 not in train samples.
# File 14414144_2 not in train samples.
# File 14414144_3 not in train samples.
# File 14418888_1 not in train samples.
# File 14418888_2 not in train samples.
# File 14419990_1 not in train samples.
# File 14419990_2 not in train samples.
# File 14420212_1 not in train samples.
# File 14420212_2 not in train samples.
# File 14422674_1 not in train samples.
# File 14422674_2 not in train samples.
# File 14426294_1 not in train samples.
# File 14426294_2 not in train samples.
# File 14426294_3 not in train samples.
# File 14432008_1 not in train samples.
# File 14434191_2 not in train samples.
# File 14434772_1 not in train samples.
# File 14434772_2 not in train samples.
# File 14434772_4 not in train samples.
# File 14438669_1 not in train samples.
# File 14438669_2 not in train samples.
# File 14658121_1 not in train samples.
# File 14658121_2 not in train samples.
# File 14658121_3 not in train samples.
# File 14658274_1 not in train samples.
# File 14658274_2 not in train samples.
# File 14658274_3 not in train samples.
# File 14660182_2 not in train samples.
# File 14661438_1 not in train samples.
# File 14661438_2 not in train samples.
# File 14662997_1 not in train samples.
# File 14663016_1 not in train samples.
# File 14663141_1 not in train samples.
# File 14663141_2 not in train samples.
# File 14663523_1 not in train samples.
# File 14665473_1 not in train samples.
# File 14666376_1 not in train samples.
# File 14667636_1 not in train samples.
# File 14668109_1 not in train samples.
# File 14668109_2 not in train samples.
# File 14668499_1 not in train samples.
# File 14668499_2 not in train samples.
# File 14668596_1 not in train samples.
# File 14668596_2 not in train samples.
# File 14669137_1 not in train samples.
# File 14669137_2 not in train samples.
# File 14669137_3 not in train samples.
# File 14669166_1 not in train samples.
# File 14669384_1 not in train samples.
# File 14669384_2 not in train samples.
# File 14669384_3 not in train samples.
# File 14669384_4 not in train samples.
# File 14669384_5 not in train samples.
# File 14669384_6 not in train samples.
# File 14669384_7 not in train samples.
# File 14670222_1 not in train samples.
# File 14670222_2 not in train samples.
# File 14670362_1 not in train samples.
# File 14670362_2 not in train samples.
# File 14671126_1 not in train samples.
# File 14671343_1 not in train samples.
# File 14671343_2 not in train samples.
# File 14671829_2 not in train samples.
# File 14671829_6 not in train samples.
# File 14671829_9 not in train samples.
# File 14672884_1 not in train samples.
# File 14672884_2 not in train samples.
# File 14673433_1 not in train samples.
# File 14673433_2 not in train samples.
# File 14673476_1 not in train samples.
# File 14673476_2 not in train samples.
# File 14673732_1 not in train samples.
# File 14673732_2 not in train samples.
# File 14673732_3 not in train samples.
# File 14673732_4 not in train samples.
# File 14674224_1 not in train samples.
# File 14675522_1 not in train samples.
# File 14675562_1 not in train samples.
# File 14675562_2 not in train samples.
# File 14675839_1 not in train samples.
# File 14675839_2 not in train samples.
# File 14675958_1 not in train samples.
# File 14676276_1 not in train samples.
# File 14676276_3 not in train samples.
# File 14676276_4 not in train samples.
# File 14676276_5 not in train samples.
# File 14677489_1 not in train samples.
# File 14677489_2 not in train samples.
# File 14677898_2 not in train samples.
# File 14677940_1 not in train samples.
# File 14677940_2 not in train samples.
# File 14678705_1 not in train samples.
# File 14678705_2 not in train samples.
# File 14678705_3 not in train samples.
# File 30385379_1 not in train samples.
# File 30385379_2 not in train samples.
# File 30386096_2 not in train samples.
# File 30386096_3 not in train samples.
# File 30386096_4 not in train samples.
# File 30386180_1 not in train samples.
# File 30386180_2 not in train samples.
# File 30386180_3 not in train samples.
# File 30406869_1 not in train samples.
# File 30407492_1 not in train samples.
# File 30407492_2 not in train samples.
# File 30407607_1 not in train samples.
# File 30407607_2 not in train samples.
# File 30407607_4 not in train samples.
# File 30407607_5 not in train samples.
# File 30407607_6 not in train samples.
# File 30407607_7 not in train samples.
# File 30407607_8 not in train samples.
# File 30415032_1 not in train samples.
# File 30416083_1 not in train samples.
# File 30416083_2 not in train samples.
# File 30416083_3 not in train samples.
# File 30416083_4 not in train samples.
# File 30420797_1 not in train samples.
# File 30420797_2 not in train samples.
# File 30420797_3 not in train samples.
# File 30423567_2 not in train samples.
# File 30424118_1 not in train samples.
# File 30424118_2 not in train samples.
# File 30428490_1 not in train samples.
# File 30430878_1 not in train samples.
# File 30430878_2 not in train samples.
# File 30431013_1 not in train samples.
# File 30431013_2 not in train samples.
# File 30437084_1 not in train samples.
# File 30437084_2 not in train samples.
# File 30439805_1 not in train samples.
# File 30439805_2 not in train samples.
# File 30439805_3 not in train samples.
# File 30447391_1 not in train samples.
# File 30447391_2 not in train samples.
# File 30447391_3 not in train samples.
# File 30451656_1 not in train samples.
# File 30451947_1 not in train samples.
# File 30451947_2 not in train samples.
# File 30459092_1 not in train samples.
# File 30462337_1 not in train samples.
# File 30462337_2 not in train samples.
# File 30462337_3 not in train samples.
# File 30462337_4 not in train samples.
# File 30462337_5 not in train samples.
# File 30462337_6 not in train samples.
# File 30462337_7 not in train samples.
# File 30471791_1 not in train samples.
# File 30471791_2 not in train samples.
# File 30471791_3 not in train samples.
# File 30475683_1 not in train samples.
# File 30475683_3 not in train samples.
# File 30480938_1 not in train samples.
# File 30484029_1 not in train samples.
# File 30484029_3 not in train samples.
# File 30486701_1 not in train samples.
# File 30486701_2 not in train samples.
# File 30486701_3 not in train samples.
# File 30486701_4 not in train samples.
# File 30486701_5 not in train samples.
# File 30488133_1 not in train samples.
# File 30488305_1 not in train samples.
# File 30488305_2 not in train samples.
# File 30496402_2 not in train samples.
# File 30499379_1 not in train samples.
# File 30504078_1 not in train samples.
# File 30506237_1 not in train samples.
# File 30506237_2 not in train samples.
# File 30506237_4 not in train samples.
# File 30506326_1 not in train samples.
# File 30506326_2 not in train samples.
# File 30513634_2 not in train samples.
# File 30518244_1 not in train samples.
# File 30518244_2 not in train samples.
# File 30518244_3 not in train samples.
# File 30518244_5 not in train samples.
# File 30526697_1 not in train samples.
# File 30526697_2 not in train samples.
# File 30526697_3 not in train samples.
# File 30526697_4 not in train samples.
# File 30528433_1 not in train samples.
# File 30528433_2 not in train samples.
# File 30528433_3 not in train samples.
# File 30528433_4 not in train samples.
# File 30534421_1 not in train samples.
# File 30534421_2 not in train samples.
# File 30542025_1 not in train samples.
# File 30542509_2 not in train samples.
# File 30548981_1 not in train samples.
# File 30549353_1 not in train samples.
# File 30550251_1 not in train samples.
# File 30550251_2 not in train samples.
# File 30550289_1 not in train samples.
# File 30550289_2 not in train samples.
# File 30550331_1 not in train samples.
# File 30554880_1 not in train samples.
# File 30554880_2 not in train samples.
# File 30554880_3 not in train samples.
# File 30554924_1 not in train samples.
# File 30554924_2 not in train samples.
# File 30558474_1 not in train samples.
# File 30558474_2 not in train samples.
# File 30558564_2 not in train samples.
# File 30560605_1 not in train samples.
# File 30560605_3 not in train samples.
# File 30560605_4 not in train samples.
# File 30560740_1 not in train samples.
# File 30564894_2 not in train samples.
# File 30564913_1 not in train samples.
# File 30565021_1 not in train samples.
# File 30565021_2 not in train samples.
# File 30565021_3 not in train samples.
# File 30565021_4 not in train samples.
# File 30565021_5 not in train samples.
# File 30571520_1 not in train samples.
# File 30571520_2 not in train samples.
# File 30571520_3 not in train samples.
# File 30571520_4 not in train samples.
# File 30571520_5 not in train samples.
# File 30571520_6 not in train samples.
# File 30571520_7 not in train samples.
# File 30571520_8 not in train samples.
# File 30580284_1 not in train samples.
# File 30580366_2 not in train samples.
# File 30580366_4 not in train samples.
# File 30586598_1 not in train samples.
# File 30586598_2 not in train samples.
# File 30586598_3 not in train samples.
# File 30586598_4 not in train samples.
# File 30586598_5 not in train samples.
# File 30588415_1 not in train samples.
# File 30591324_1 not in train samples.
# File 30591324_2 not in train samples.
# File 30591324_3 not in train samples.
# File 30591337_2 not in train samples.
# File 30593264_1 not in train samples.
# File 30593264_2 not in train samples.
# File 30594180_1 not in train samples.
# File 30598511_1 not in train samples.
# File 30598511_2 not in train samples.
# File 30598511_3 not in train samples.
# File 30603462_1 not in train samples.
# File 30604422_1 not in train samples.
# File 30604422_2 not in train samples.
# File 30611457_1 not in train samples.
# File 30611457_2 not in train samples.
# File 30611457_3 not in train samples.
# File 30611457_4 not in train samples.
# File 30613304_1 not in train samples.
# File 30614170_1 not in train samples.
# File 30616911_1 not in train samples.
# File 30620728_1 not in train samples.
# File 30620728_2 not in train samples.
# File 30622804_1 not in train samples.
# File 30625900_2 not in train samples.
# File 30626266_1 not in train samples.
# File 30626718_1 not in train samples.
# File 30626718_2 not in train samples.
# File 30630091_1 not in train samples.
# File 30630091_2 not in train samples.
# File 30631741_1 not in train samples.
# File 30631741_2 not in train samples.
# File 30631959_1 not in train samples.
# File 30632791_1 not in train samples.
# File 30632791_2 not in train samples.
# File 30632791_3 not in train samples.
# File 30632791_4 not in train samples.
# File 30632791_5 not in train samples.
# File 30632791_6 not in train samples.
# File 30632791_7 not in train samples.
# File 30632791_8 not in train samples.
# File 30632791_9 not in train samples.
# File 30632791_10 not in train samples.
# File 30632791_11 not in train samples.
# File 30632791_12 not in train samples.
# File 30632822_1 not in train samples.
# File 30632822_2 not in train samples.
# File 30641011_3 not in train samples.
# File 30641144_1 not in train samples.
# File 30641144_2 not in train samples.
# File 30641144_3 not in train samples.
# File 30644511_1 not in train samples.
# File 30644511_2 not in train samples.
# File 30644511_3 not in train samples.
# File 30644511_4 not in train samples.
# File 30644511_5 not in train samples.
# File 30653614_2 not in train samples.
# File 30654526_1 not in train samples.
# File 30654526_2 not in train samples.
# File 30659540_1 not in train samples.
# File 30659540_2 not in train samples.
# File 30659540_3 not in train samples.
# File 30663262_1 not in train samples.
# File 30663262_2 not in train samples.
# File 30663262_3 not in train samples.
# File 30664484_1 not in train samples.
# File 30664484_2 not in train samples.
# File 30664484_3 not in train samples.
# File 30670272_1 not in train samples.
# File 30674568_1 not in train samples.
# File 30682425_1 not in train samples.
# File 30684884_1 not in train samples.
# File 30684884_2 not in train samples.
# File 30688721_1 not in train samples.
# File 30690865_1 not in train samples.
# File 30690865_2 not in train samples.
# File 30691218_1 not in train samples.
# File 30691258_1 not in train samples.
# File 30701160_1 not in train samples.
# File 30701160_2 not in train samples.
# File 30701160_3 not in train samples.
# File 30709717_1 not in train samples.
# File 30709717_2 not in train samples.
# File 30709920_1 not in train samples.
# File 30709920_2 not in train samples.
# File 30709920_3 not in train samples.
# File 30712848_2 not in train samples.
# File 30712848_3 not in train samples.
# File 30718944_1 not in train samples.
# File 30729164_1 not in train samples.
# File 30729164_2 not in train samples.
# File 30734623_1 not in train samples.
# File 30737227_1 not in train samples.
# File 30737227_2 not in train samples.
# File 30737227_3 not in train samples.
# File 30765003_1 not in train samples.
# File 30765003_2 not in train samples.
# File 30765003_3 not in train samples.
# File 30765006_1 not in train samples.
# File 30765006_2 not in train samples.
# File 30765131_1 not in train samples.
# File 30765131_2 not in train samples.
# File 30765131_4 not in train samples.
# File 30773912_1 not in train samples.
# File 30773912_2 not in train samples.
# File 30779375_1 not in train samples.
# File 30779375_2 not in train samples.
# File 30779375_3 not in train samples.
# File 30779375_4 not in train samples.
# File 30779375_5 not in train samples.
# File 30784909_1 not in train samples.
# File 30790752_1 not in train samples.
# File 30790752_2 not in train samples.
# File 30793062_1 not in train samples.
# File 30793062_2 not in train samples.
# File 30793540_1 not in train samples.
# File 30793540_2 not in train samples.
# File 30796558_1 not in train samples.
# File 30805388_1 not in train samples.
# File 30980551_1 not in train samples.
# File 30980551_2 not in train samples.
# File 30980551_3 not in train samples.
# File 31009070_1 not in train samples.
# File 31009070_2 not in train samples.
# File 31077454_1 not in train samples.
# File 31454467_1 not in train samples.
# File 31454467_2 not in train samples.
# File 31539421_3 not in train samples.
# File 31539421_4 not in train samples.
# File 31539421_5 not in train samples.
# File 31539421_6 not in train samples.
# File 31681707_1 not in train samples.
# File 31681707_2 not in train samples.
# File 31681707_3 not in train samples.
# File 31708555_1 not in train samples.
# File 31713883_1 not in train samples.
# File 31713883_2 not in train samples.
# File 31713883_3 not in train samples.
# File 31716707_1 not in train samples.
# File 31716707_2 not in train samples.
# File 31721449_1 not in train samples.
# File 31721449_2 not in train samples.
# File 31721475_2 not in train samples.
# File 31723652_1 not in train samples.
# File 31723718_2 not in train samples.
# File 31726068_1 not in train samples.
# File 31726068_2 not in train samples.
# File 31726068_3 not in train samples.
# File 31726098_1 not in train samples.
# File 31730740_1 not in train samples.
# File 31730740_2 not in train samples.
# File 31732908_1 not in train samples.
# File 31737319_1 not in train samples.
# File 31737319_2 not in train samples.
# File 31742023_2 not in train samples.
# File 31742023_3 not in train samples.
# File 31742059_1 not in train samples.
# File 31744026_1 not in train samples.
# File 31744026_2 not in train samples.
# File 31744026_3 not in train samples.
# File 31744038_1 not in train samples.
# File 31750726_1 not in train samples.
# File 31750940_1 not in train samples.
# File 31750940_2 not in train samples.
# File 31750940_3 not in train samples.
# File 31752038_1 not in train samples.
# File 31752038_2 not in train samples.
# File 31757382_1 not in train samples.
# File 31757382_3 not in train samples.
# File 31759464_1 not in train samples.
# File 31759464_2 not in train samples.
# File 31767426_1 not in train samples.
# File 31768437_1 not in train samples.
# File 31768457_1 not in train samples.
# File 31772119_1 not in train samples.
# File 31772119_2 not in train samples.
# File 31772119_3 not in train samples.
# File 31776596_1 not in train samples.
# File 31776596_2 not in train samples.
# File 31776596_3 not in train samples.
# File 31781601_1 not in train samples.
# File 31781601_2 not in train samples.
# File 31781601_3 not in train samples.
# File 31783643_1 not in train samples.
# File 32576555_1 not in train samples.
# File 33018631_1 not in train samples.
# File 33018631_2 not in train samples.
# File 33222250_3 not in train samples.
# File 33222637_1 not in train samples.
# File 33633740_1 not in train samples.
# File 33633779_1 not in train samples.
# File 33633779_2 not in train samples.
# File 33633779_3 not in train samples.
# File 33645533_1 not in train samples.
# File 33645533_2 not in train samples.
# File 33677015_1 not in train samples.
# File 12842139_1 not in train samples.
# File 12842828_1 not in train samples.
# File 12842828_2 not in train samples.
# File 12845676_2 not in train samples.
# File 12845773_1 not in train samples.
# File 12845773_2 not in train samples.
# File 12845773_3 not in train samples.
# File 12845773_4 not in train samples.
# File 12845775_1 not in train samples.
# File 12845775_2 not in train samples.
# File 12845775_3 not in train samples.
# File 12850869_1 not in train samples.
# File 12850869_2 not in train samples.
# File 12851205_1 not in train samples.
# File 12855064_1 not in train samples.
# File 12858403_1 not in train samples.
# File 12858403_3 not in train samples.
# File 12858403_4 not in train samples.
# File 12858403_5 not in train samples.
# File 12860405_1 not in train samples.
# File 12860405_2 not in train samples.
# File 12860405_3 not in train samples.
# File 12869707_1 not in train samples.
# File 12869707_2 not in train samples.
# File 12870177_1 not in train samples.
# File 12870177_2 not in train samples.
# File 12873389_1 not in train samples.
# File 12876317_1 not in train samples.
# File 12876317_2 not in train samples.
# File 12876357_1 not in train samples.
# File 12876357_2 not in train samples.
# File 12882281_1 not in train samples.
# File 12901653_1 not in train samples.
# File 12901653_2 not in train samples.
# File 13030567_1 not in train samples.
# File 13030567_2 not in train samples.
# File 13052957_1 not in train samples.
# File 13059805_1 not in train samples.
# File 13059805_2 not in train samples.
# File 13059805_3 not in train samples.
# File 13059805_4 not in train samples.
# File 13059805_5 not in train samples.
# File 13059805_6 not in train samples.
# File 13059805_7 not in train samples.
# File 13059805_8 not in train samples.
# File 13059805_9 not in train samples.
# File 13059807_2 not in train samples.
# File 13107206_1 not in train samples.
# File 13123762_1 not in train samples.
# File 13123762_2 not in train samples.
# File 13196322_1 not in train samples.
# File 13196322_2 not in train samples.
# File 13196322_3 not in train samples.
# File 13245714_1 not in train samples.
# File 13246645_1 not in train samples.
# File 13246645_2 not in train samples.
# File 13272218_1 not in train samples.
# File 13272218_3 not in train samples.
# File 13284493_2 not in train samples.
# File 13284493_3 not in train samples.
# File 13285941_1 not in train samples.
# File 13285941_2 not in train samples.
# File 13285941_3 not in train samples.
# File 13299159_1 not in train samples.
# File 13332658_1 not in train samples.
# File 13350432_1 not in train samples.
# File 13379549_1 not in train samples.
# File 13379549_2 not in train samples.
# File 13379549_3 not in train samples.
# File 13384084_1 not in train samples.
# File 13384084_2 not in train samples.
# File 13384084_3 not in train samples.
# File 13389473_1 not in train samples.
# File 13394158_1 not in train samples.
# File 13398095_2 not in train samples.
# File 13427417_2 not in train samples.
# File 13427417_3 not in train samples.
# File 13446105_1 not in train samples.
# File 13450081_2 not in train samples.
# File 13450081_3 not in train samples.
# File 13452119_2 not in train samples.
# File 13452732_1 not in train samples.
# File 13452732_2 not in train samples.
# File 13455266_1 not in train samples.
# File 13455360_3 not in train samples.
# File 13455420_1 not in train samples.
# File 13455420_2 not in train samples.
# File 13456333_1 not in train samples.
# File 13456333_2 not in train samples.
# File 13456333_3 not in train samples.
# File 13456896_1 not in train samples.
# File 13458695_1 not in train samples.
# File 13460630_1 not in train samples.
# File 13461530_1 not in train samples.
# File 13461530_2 not in train samples.
# File 13462130_1 not in train samples.
# File 13462130_2 not in train samples.
# File 13465892_1 not in train samples.
# File 13467036_1 not in train samples.
# File 13470050_1 not in train samples.
# File 13470831_1 not in train samples.
# File 13470831_2 not in train samples.
# File 13472253_1 not in train samples.
# File 13472253_2 not in train samples.
# File 13472253_3 not in train samples.
# File 13472253_4 not in train samples.
# File 13473247_1 not in train samples.
# File 13473247_2 not in train samples.
# File 13473247_3 not in train samples.
# File 13473247_4 not in train samples.
# File 13473874_1 not in train samples.
# File 13473874_2 not in train samples.
# File 13473877_1 not in train samples.
# File 13473877_2 not in train samples.
# File 13474316_1 not in train samples.
# File 13474316_2 not in train samples.
# File 13474537_1 not in train samples.
# File 13475526_1 not in train samples.
# File 13475526_2 not in train samples.
# File 13476634_1 not in train samples.
# File 13476634_2 not in train samples.
# File 13476634_3 not in train samples.
# File 13476735_1 not in train samples.
# File 13476735_2 not in train samples.
# File 13479046_1 not in train samples.
# File 13479046_2 not in train samples.
# File 13480152_1 not in train samples.
# File 13480245_1 not in train samples.
# File 13480245_2 not in train samples.
# File 13480245_3 not in train samples.
# File 13481672_1 not in train samples.
# File 13483920_1 not in train samples.
# File 13486476_1 not in train samples.
# File 13486476_2 not in train samples.
# File 13488589_1 not in train samples.
# File 13490266_1 not in train samples.
# File 13490266_2 not in train samples.
# File 13490663_1 not in train samples.
# File 13490663_2 not in train samples.
# File 13490663_3 not in train samples.
# File 13490663_4 not in train samples.
# File 13491141_1 not in train samples.
# File 13491549_1 not in train samples.
# File 13492128_1 not in train samples.
# File 13498257_2 not in train samples.
# File 13498257_3 not in train samples.
# File 13498586_1 not in train samples.
# File 13499058_1 not in train samples.
# File 13499058_2 not in train samples.
# File 13501160_1 not in train samples.
# File 13501160_3 not in train samples.
# File 13501379_3 not in train samples.
# File 13501659_1 not in train samples.
# File 13502559_1 not in train samples.
# File 13503337_1 not in train samples.
# File 13503337_2 not in train samples.
# File 13503863_1 not in train samples.
# File 13503863_2 not in train samples.
# File 13504586_1 not in train samples.
# File 13504718_1 not in train samples.
# File 13504718_2 not in train samples.
# File 13506478_1 not in train samples.
# File 13511770_1 not in train samples.
# File 13511770_2 not in train samples.
# File 13511770_3 not in train samples.
# File 13561999_1 not in train samples.
# File 13573024_1 not in train samples.
# File 13573521_2 not in train samples.
# File 13584961_1 not in train samples.
# File 13584961_2 not in train samples.
# File 13584961_3 not in train samples.
# File 13585848_1 not in train samples.
# File 13585905_1 not in train samples.
# File 13585905_2 not in train samples.
# File 13586085_1 not in train samples.
# File 13586085_2 not in train samples.
# File 13587646_1 not in train samples.
# File 13587646_2 not in train samples.
# File 13590627_1 not in train samples.
# File 13590627_4 not in train samples.
# File 13590673_1 not in train samples.
# File 13590673_2 not in train samples.
# File 13590736_1 not in train samples.
# File 13591202_1 not in train samples.
# File 13591250_1 not in train samples.
# File 13591250_2 not in train samples.
# File 13591250_3 not in train samples.
# File 13591250_4 not in train samples.
# File 13591250_5 not in train samples.
# File 13591250_6 not in train samples.
# File 13591250_7 not in train samples.
# File 13591250_8 not in train samples.
# File 13591250_9 not in train samples.
# File 13591250_10 not in train samples.
# File 13591250_11 not in train samples.
# File 13591250_12 not in train samples.
# File 13591250_14 not in train samples.
# File 13592619_1 not in train samples.
# File 13594328_1 not in train samples.
# File 13594604_1 not in train samples.
# File 13594604_2 not in train samples.
# File 13594631_1 not in train samples.
# File 13594631_2 not in train samples.
# File 13594631_3 not in train samples.
# File 13595169_1 not in train samples.
# File 13595169_2 not in train samples.
# File 13595169_3 not in train samples.
# File 13596220_1 not in train samples.
# File 13596220_2 not in train samples.
# File 13606532_1 not in train samples.
# File 13606532_2 not in train samples.
# File 13606532_3 not in train samples.
# File 13608162_1 not in train samples.
# File 13608520_1 not in train samples.
# File 13615442_1 not in train samples.
# File 13615812_1 not in train samples.
# File 13617363_1 not in train samples.
# File 13617363_2 not in train samples.
# File 13621261_1 not in train samples.
# File 13621261_2 not in train samples.
# File 13621261_3 not in train samples.
# File 13621261_4 not in train samples.
# File 13621261_5 not in train samples.
# File 13621261_9 not in train samples.
# File 13639196_1 not in train samples.
# File 13639196_2 not in train samples.
# File 13639196_3 not in train samples.
# File 13640101_1 not in train samples.
# File 13640101_2 not in train samples.
# File 13640101_3 not in train samples.
# File 13640101_4 not in train samples.
# File 13640101_5 not in train samples.
# File 13842795_1 not in train samples.
# File 13842795_2 not in train samples.
# File 13843271_1 not in train samples.
# File 13844028_1 not in train samples.
# File 13845714_1 not in train samples.
# File 13845939_2 not in train samples.
# File 13849923_1 not in train samples.
# File 13850034_1 not in train samples.
# File 13850034_3 not in train samples.
# File 13850336_1 not in train samples.
# File 13850336_2 not in train samples.
# File 13850783_1 not in train samples.
# File 13850783_2 not in train samples.
# File 13852977_1 not in train samples.
# File 13854061_1 not in train samples.
# File 13855833_1 not in train samples.
# File 13856018_1 not in train samples.
# File 13856778_1 not in train samples.
# File 13856778_2 not in train samples.
# File 13858458_1 not in train samples.
# File 13858458_2 not in train samples.
# File 13858458_3 not in train samples.
# File 13858717_1 not in train samples.
# File 13858854_1 not in train samples.
# File 13859827_1 not in train samples.
# File 13860689_1 not in train samples.
# File 13861415_1 not in train samples.
# File 13861494_1 not in train samples.
# File 13861721_1 not in train samples.
# File 13863919_1 not in train samples.
# File 13863919_2 not in train samples.
# File 13863919_3 not in train samples.
# File 13864614_1 not in train samples.
# File 13864614_2 not in train samples.
# File 13864614_3 not in train samples.
# File 13864614_4 not in train samples.
# File 13865609_1 not in train samples.
# File 13865833_1 not in train samples.
# File 13865833_2 not in train samples.
# File 13865833_3 not in train samples.
# File 13865833_4 not in train samples.
# File 13866148_1 not in train samples.
# File 13866256_1 not in train samples.
# File 13866450_1 not in train samples.
# File 13866450_2 not in train samples.
# File 13867769_1 not in train samples.
# File 13945984_1 not in train samples.
# File 13946706_1 not in train samples.
# File 13946706_3 not in train samples.
# File 13946706_4 not in train samples.
# File 13946706_5 not in train samples.
# File 13946706_6 not in train samples.
# File 14014660_1 not in train samples.
# File 14014660_2 not in train samples.
# File 14014774_1 not in train samples.
# File 14014774_2 not in train samples.
# File 14014847_1 not in train samples.
# File 14014847_2 not in train samples.
# File 14014956_2 not in train samples.
# File 14015131_2 not in train samples.
# File 14015131_3 not in train samples.
# File 14019323_1 not in train samples.
# File 14020935_1 not in train samples.
# File 14020935_2 not in train samples.
# File 14022486_1 not in train samples.
# File 14022486_2 not in train samples.
# File 14023005_1 not in train samples.
# File 14024615_1 not in train samples.
# File 14024615_2 not in train samples.
# File 14025797_1 not in train samples.
# File 14025978_1 not in train samples.
# File 14025978_2 not in train samples.
# File 14026050_1 not in train samples.
# File 14026050_2 not in train samples.
# File 14026470_1 not in train samples.
# File 14026470_2 not in train samples.
# File 14026470_3 not in train samples.
# File 14026470_4 not in train samples.
# File 14026503_1 not in train samples.
# File 14026532_1 not in train samples.
# File 14026532_2 not in train samples.
# ...
# File 14670842_1 not in test samples.
# File 14670842_2 not in test samples.
# File 14671055_1 not in test samples.
# File 14671055_2 not in test samples.
# File 14671058_1 not in test samples.
# File 14672794_1 not in test samples.
# File 14672794_2 not in test samples.
# File 14673330_1 not in test samples.
# File 14673330_2 not in test samples.
# File 14673502_1 not in test samples.
# File 14673502_2 not in test samples.
# File 14673538_2 not in test samples.
# File 14674235_1 not in test samples.
# File 14674737_1 not in test samples.
# File 14674737_2 not in test samples.
# File 14674737_3 not in test samples.
# File 14675644_1 not in test samples.
# File 14675644_2 not in test samples.
# File 14675644_3 not in test samples.
# File 14676868_1 not in test samples.
# File 14678374_1 not in test samples.
# File 14678374_2 not in test samples.
# File 14678615_1 not in test samples.
# File 14678615_2 not in test samples.
# File 14678670_2 not in test samples.
# File 30386052_1 not in test samples.
# File 30386052_2 not in test samples.
# File 30389867_1 not in test samples.
# File 30389867_2 not in test samples.
# File 30390500_1 not in test samples.
# File 30394057_1 not in test samples.
# File 30394057_2 not in test samples.
# File 30395850_1 not in test samples.
# File 30398559_1 not in test samples.
# File 30398559_2 not in test samples.
# File 30398559_3 not in test samples.
# File 30399174_1 not in test samples.
# File 30399246_1 not in test samples.
# File 30399246_2 not in test samples.
# File 30404483_1 not in test samples.
# File 30404483_2 not in test samples.
# File 30404483_3 not in test samples.
# File 30415138_1 not in test samples.
# File 30415138_2 not in test samples.
# File 30415842_1 not in test samples.
# File 30415842_2 not in test samples.
# File 30415842_3 not in test samples.
# File 30415853_1 not in test samples.
# File 30415853_2 not in test samples.
# File 30424025_1 not in test samples.
# File 30424025_2 not in test samples.
# File 30428481_1 not in test samples.
# File 30430910_1 not in test samples.
# File 30430910_2 not in test samples.
# File 30438203_1 not in test samples.
# File 30438203_2 not in test samples.
# File 30438203_3 not in test samples.
# File 30438203_4 not in test samples.
# File 30438203_5 not in test samples.
# File 30439166_1 not in test samples.
# File 30447339_2 not in test samples.
# File 30451625_1 not in test samples.
# File 30451625_2 not in test samples.
# File 30451625_3 not in test samples.
# File 30451625_4 not in test samples.
# File 30451625_5 not in test samples.
# File 30451625_6 not in test samples.
# File 30451625_7 not in test samples.
# File 30457365_1 not in test samples.
# File 30461427_2 not in test samples.
# File 30461441_1 not in test samples.
# File 30461441_2 not in test samples.
# File 30462334_1 not in test samples.
# File 30462334_2 not in test samples.
# File 30462334_3 not in test samples.
# File 30462334_4 not in test samples.
# File 30466436_1 not in test samples.
# File 30466436_2 not in test samples.
# File 30466531_1 not in test samples.
# File 30467951_1 not in test samples.
# File 30467951_2 not in test samples.
# File 30467951_3 not in test samples.
# File 30471819_1 not in test samples.
# File 30481231_1 not in test samples.
# File 30481231_2 not in test samples.
# File 30481231_3 not in test samples.
# File 30488228_1 not in test samples.
# File 30488228_2 not in test samples.
# File 30488228_3 not in test samples.
# File 30488228_4 not in test samples.
# File 30488228_5 not in test samples.
# File 30488228_6 not in test samples.
# File 30490648_1 not in test samples.
# File 30491779_1 not in test samples.
# File 30491779_2 not in test samples.
# File 30491816_1 not in test samples.
# File 30491816_2 not in test samples.
# File 30491816_3 not in test samples.
# File 30491857_1 not in test samples.
# File 30491857_2 not in test samples.
# File 30491857_3 not in test samples.
# File 30491906_1 not in test samples.
# File 30491906_2 not in test samples.
# File 30491906_3 not in test samples.
# File 30491906_4 not in test samples.
# File 30497977_1 not in test samples.
# File 30497977_2 not in test samples.
# File 30497977_3 not in test samples.
# File 30497977_4 not in test samples.
# File 30500196_1 not in test samples.
# File 30504346_1 not in test samples.
# File 30505119_1 not in test samples.
# File 30505119_2 not in test samples.
# File 30505306_1 not in test samples.
# File 30505306_2 not in test samples.
# File 30505306_4 not in test samples.
# File 30505306_5 not in test samples.
# File 30505306_6 not in test samples.
# File 30507532_1 not in test samples.
# File 30507540_1 not in test samples.
# File 30511291_1 not in test samples.
# File 30521749_1 not in test samples.
# File 30525151_1 not in test samples.
# File 30526433_1 not in test samples.
# File 30526433_2 not in test samples.
# File 30526559_1 not in test samples.
# File 30526559_2 not in test samples.
# File 30526559_3 not in test samples.
# File 30526559_4 not in test samples.
# File 30526559_5 not in test samples.
# File 30526559_6 not in test samples.
# File 30526559_7 not in test samples.
# File 30526559_8 not in test samples.
# File 30526559_9 not in test samples.
# File 30527087_1 not in test samples.
# File 30527087_2 not in test samples.
# File 30527087_3 not in test samples.
# File 30527087_4 not in test samples.
# File 30527087_5 not in test samples.
# File 30527087_6 not in test samples.
# File 30527087_7 not in test samples.
# File 30527087_8 not in test samples.
# File 30527087_9 not in test samples.
# File 30527087_10 not in test samples.
# File 30527087_11 not in test samples.
# File 30532580_1 not in test samples.
# File 30532580_2 not in test samples.
# File 30532580_3 not in test samples.
# File 30533168_1 not in test samples.
# File 30533168_2 not in test samples.
# File 30533168_3 not in test samples.
# File 30536136_1 not in test samples.
# File 30536136_2 not in test samples.
# File 30536136_3 not in test samples.
# File 30536136_4 not in test samples.
# File 30536136_5 not in test samples.
# File 30536136_6 not in test samples.
# File 30536136_7 not in test samples.
# File 30541083_1 not in test samples.
# File 30542596_1 not in test samples.
# File 30542596_2 not in test samples.
# File 30542596_3 not in test samples.
# File 30542596_4 not in test samples.
# File 30542596_5 not in test samples.
# File 30542596_6 not in test samples.
# File 30542596_7 not in test samples.
# File 30542596_9 not in test samples.
# File 30548876_1 not in test samples.
# File 30548876_3 not in test samples.
# File 30550201_1 not in test samples.
# File 30550201_2 not in test samples.
# File 30555057_1 not in test samples.
# File 30558443_1 not in test samples.
# File 30558443_2 not in test samples.
# File 30561563_1 not in test samples.
# File 30561702_1 not in test samples.
# File 30561702_2 not in test samples.
# File 30570212_1 not in test samples.
# File 30570212_2 not in test samples.
# File 30571387_1 not in test samples.
# File 30572715_1 not in test samples.
# File 30575817_1 not in test samples.
# File 30575857_2 not in test samples.
# File 30575857_3 not in test samples.
# File 30576301_1 not in test samples.
# File 30577071_1 not in test samples.
# File 30577071_2 not in test samples.
# File 30577071_3 not in test samples.
# File 30577556_1 not in test samples.
# File 30577556_2 not in test samples.
# File 30583625_1 not in test samples.
# File 30583625_2 not in test samples.
# File 30583636_1 not in test samples.
# File 30583636_2 not in test samples.
# File 30583636_3 not in test samples.
# File 30583636_4 not in test samples.
# File 30585978_1 not in test samples.
# File 30585978_2 not in test samples.
# File 30587336_1 not in test samples.
# File 30587336_2 not in test samples.
# File 30597577_1 not in test samples.
# File 30597577_2 not in test samples.
# File 30597577_3 not in test samples.
# File 30597853_1 not in test samples.
# File 30597853_2 not in test samples.
# File 30597853_3 not in test samples.
# File 30597853_4 not in test samples.
# File 30603595_1 not in test samples.
# File 30608484_1 not in test samples.
# File 30608484_2 not in test samples.
# File 30608946_1 not in test samples.
# File 30608946_2 not in test samples.
# File 30608946_3 not in test samples.
# File 30608946_4 not in test samples.
# File 30611280_1 not in test samples.
# File 30611280_2 not in test samples.
# File 30617442_1 not in test samples.
# File 30617442_2 not in test samples.
# File 30617442_3 not in test samples.
# File 30620870_1 not in test samples.
# File 30620870_2 not in test samples.
# File 30627221_1 not in test samples.
# File 30627221_2 not in test samples.
# File 30630689_1 not in test samples.
# File 30630689_2 not in test samples.
# File 30631655_1 not in test samples.
# File 30631655_2 not in test samples.
# File 30631655_3 not in test samples.
# File 30631777_1 not in test samples.
# File 30631777_2 not in test samples.
# File 30631814_1 not in test samples.
# File 30631814_2 not in test samples.
# File 30636407_1 not in test samples.
# File 30636407_2 not in test samples.
# File 30636407_3 not in test samples.
# File 30636407_4 not in test samples.
# File 30636407_5 not in test samples.
# File 30636407_6 not in test samples.
# File 30641117_1 not in test samples.
# File 30641263_1 not in test samples.
# File 30641263_2 not in test samples.
# File 30641263_3 not in test samples.
# File 30641987_1 not in test samples.
# File 30641987_2 not in test samples.
# File 30641987_3 not in test samples.
# File 30641987_4 not in test samples.
# File 30644643_1 not in test samples.
# File 30644643_2 not in test samples.
# File 30647927_1 not in test samples.
# File 30647927_2 not in test samples.
# File 30649232_1 not in test samples.
# File 30654889_1 not in test samples.
# File 30658553_1 not in test samples.
# File 30658687_1 not in test samples.
# File 30658687_2 not in test samples.
# File 30658705_1 not in test samples.
# File 30658705_2 not in test samples.
# File 30659520_1 not in test samples.
# File 30659798_1 not in test samples.
# File 30660601_1 not in test samples.
# File 30660607_1 not in test samples.
# File 30660607_2 not in test samples.
# File 30660607_3 not in test samples.
# File 30660607_4 not in test samples.
# File 30663183_1 not in test samples.
# File 30663183_2 not in test samples.
# File 30663322_1 not in test samples.
# File 30663322_2 not in test samples.
# File 30663322_4 not in test samples.
# File 30663322_5 not in test samples.
# File 30663322_6 not in test samples.
# File 30663322_7 not in test samples.
# File 30663322_8 not in test samples.
# File 30663322_9 not in test samples.
# File 30663628_1 not in test samples.
# File 30663628_2 not in test samples.
# File 30663628_3 not in test samples.
# File 30668023_1 not in test samples.
# File 30668023_2 not in test samples.
# File 30668323_1 not in test samples.
# File 30677056_1 not in test samples.
# File 30677090_1 not in test samples.
# File 30677090_2 not in test samples.
# File 30677090_3 not in test samples.
# File 30695840_1 not in test samples.
# File 30695840_2 not in test samples.
# File 30713756_1 not in test samples.
# File 30713756_2 not in test samples.
# File 30721519_1 not in test samples.
# File 30739023_1 not in test samples.
# File 30739023_2 not in test samples.
# File 30739023_3 not in test samples.
# File 30739023_4 not in test samples.
# File 30739023_5 not in test samples.
# File 30739023_6 not in test samples.
# File 30739023_7 not in test samples.
# File 30739023_8 not in test samples.
# File 30739023_9 not in test samples.
# File 30739023_10 not in test samples.
# File 30739023_11 not in test samples.
# File 30739023_12 not in test samples.
# File 30739023_13 not in test samples.
# File 30739023_14 not in test samples.
# File 30739023_15 not in test samples.
# File 30739023_16 not in test samples.
# File 30744435_1 not in test samples.
# File 30754294_2 not in test samples.
# File 30754357_1 not in test samples.
# File 30762980_1 not in test samples.
# File 30762980_2 not in test samples.
# File 30762980_3 not in test samples.
# File 30765154_1 not in test samples.
# File 30765154_2 not in test samples.
# File 30773726_1 not in test samples.
# File 30777667_1 not in test samples.
# File 30777667_2 not in test samples.
# File 30777667_3 not in test samples.
# File 30777933_1 not in test samples.
# File 30777933_2 not in test samples.
# File 30777933_3 not in test samples.
# File 30777933_4 not in test samples.
# File 30777933_5 not in test samples.
# File 30777933_6 not in test samples.
# File 30777933_7 not in test samples.
# File 30777933_8 not in test samples.
# File 30777933_9 not in test samples.
# File 30777933_10 not in test samples.
# File 30777933_11 not in test samples.
# File 30777933_12 not in test samples.
# File 30777933_13 not in test samples.
# File 30777933_14 not in test samples.
# File 30777933_15 not in test samples.
# File 30777933_16 not in test samples.
# File 30777933_17 not in test samples.
# File 30791003_1 not in test samples.
# File 30791003_2 not in test samples.
# File 30791003_3 not in test samples.
# File 30791003_4 not in test samples.
# File 30917735_1 not in test samples.
# File 31019775_1 not in test samples.
# File 31019775_2 not in test samples.
# File 31019775_3 not in test samples.
# File 31026449_1 not in test samples.
# File 31442389_1 not in test samples.
# File 31442389_2 not in test samples.
# File 31442389_4 not in test samples.
# File 31483246_1 not in test samples.
# File 31483246_2 not in test samples.
# File 31662212_1 not in test samples.
# File 31687438_1 not in test samples.
# File 31687438_2 not in test samples.
# File 31687438_3 not in test samples.
# File 31688744_1 not in test samples.
# File 31688744_2 not in test samples.
# File 31704873_1 not in test samples.
# File 31706013_1 not in test samples.
# File 31708632_1 not in test samples.
# File 31713922_1 not in test samples.
# File 31713922_2 not in test samples.
# File 31714193_1 not in test samples.
# File 31714193_2 not in test samples.
# File 31721307_1 not in test samples.
# File 31721307_2 not in test samples.
# File 31721514_1 not in test samples.
# File 31723777_1 not in test samples.
# File 31723777_2 not in test samples.
# File 31723777_3 not in test samples.
# File 31730595_1 not in test samples.
# File 31735111_1 not in test samples.
# File 31735111_2 not in test samples.
# File 31742982_1 not in test samples.
# File 31746301_1 not in test samples.
# File 31746326_1 not in test samples.
# File 31746326_2 not in test samples.
# File 31748397_1 not in test samples.
# File 31748397_2 not in test samples.
# File 31748397_3 not in test samples.
# File 31748583_1 not in test samples.
# File 31749691_1 not in test samples.
# File 31749691_2 not in test samples.
# File 31750807_1 not in test samples.
# File 31750807_2 not in test samples.
# File 31751889_1 not in test samples.
# File 31751889_2 not in test samples.
# File 31751889_3 not in test samples.
# File 31753065_1 not in test samples.
# File 31753065_2 not in test samples.
# File 31753065_3 not in test samples.
# File 31753065_4 not in test samples.
# File 31754206_1 not in test samples.
# File 31755383_1 not in test samples.
# File 31755383_2 not in test samples.
# File 31755383_3 not in test samples.
# File 31761885_1 not in test samples.
# File 31761885_2 not in test samples.
# File 31765387_1 not in test samples.
# File 31765387_2 not in test samples.
# File 31768317_1 not in test samples.
# File 31777526_1 not in test samples.
# File 31777526_2 not in test samples.
# File 31777696_1 not in test samples.
# File 31782617_1 not in test samples.
# File 31782617_2 not in test samples.
# File 31783631_1 not in test samples.
# File 31783670_1 not in test samples.
# File 31783670_2 not in test samples.
# File 31785523_1 not in test samples.
# File 31786704_1 not in test samples.
# File 31786704_2 not in test samples.
# File 31788539_1 not in test samples.
# File 32294566_1 not in test samples.
# File 32294566_2 not in test samples.
# File 32382872_1 not in test samples.
# File 32726541_1 not in test samples.
# File 32733479_1 not in test samples.
# File 32738459_1 not in test samples.
# File 32760026_1 not in test samples.
# File 32760026_2 not in test samples.
# File 32833386_1 not in test samples.
# File 32957460_1 not in test samples.
# File 32957460_2 not in test samples.
# File 32976641_1 not in test samples.
# File 33662039_1 not in test samples.
# File 33676864_1 not in test samples.
# File 33676864_2 not in test samples.
# File 33676864_3 not in test samples.
# File 33676864_4 not in test samples.
# File 33676864_5 not in test samples.
# File 33677019_1 not in test samples.
# File 33677019_2 not in test samples.
# File 33677053_1 not in test samples.

# %% [markdown]
# ### EDA and Pre-Processing

# %%
# Keep sentences classified only as noHate and hate - Train Sample
cleanPosts_tr = annot_tr[(annot_tr['label'] != 'relation') & (annot_tr['label'] != 'idk/skip')]
# Reset index
cleanPosts_tr = cleanPosts_tr.reset_index(drop=True)

# Keep sentences classified only as noHate and hate - Test Sample
cleanPosts_ts = annot_ts[(annot_ts['label'] != 'relation') & (annot_ts['label'] != 'idk/skip')]
# Reset index
cleanPosts_ts = cleanPosts_ts.reset_index(drop=True)

# %% [markdown]
# #### WordCloud for Posts Classified as Hate

# %%
# Update STOPWORDS
stop_words = STOPWORDS.update(["https", "S"])

# %% [markdown]
# Train Sample

# %%
# WordCloud for posts classified as hate - Train Sample
wc_hate_tr = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts_tr['message'][cleanPosts_tr['label']=='hate']))
# Generate plot
plt.imshow(wc_hate_tr)
plt.axis("off")
plt.show()

# %% [markdown]
# Test Sample

# %%
# WordCloud for posts classified as hate - Test Sample
wc_hate_ts = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts_ts['message'][cleanPosts_ts['label']=='hate']))
# Generate plot
plt.imshow(wc_hate_ts)
plt.axis("off")
plt.show()

# %% [markdown]
# #### WordCloud for Posts Classified as noHate

# %% [markdown]
# Train Sample

# %%
# WordCloud for posts classified as noHate - Train Sample
wc_noHate_tr = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts_tr['message'][cleanPosts_tr['label']=='noHate']))
# Generate plot
plt.imshow(wc_noHate_tr)
plt.axis("off")
plt.show()

# %% [markdown]
# Test Sample

# %%
# WordCloud for posts classified as noHate - Test Sample
wc_noHate_ts = WordCloud(stopwords=STOPWORDS, background_color='white').generate(' '.join(cleanPosts_ts['message'][cleanPosts_ts['label']=='noHate']))
# Generate plot
plt.imshow(wc_noHate_ts)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Recreating Paper Results

# %% [markdown]
# #### Pre-Process text with SpaCy

# %% [markdown]
# Train Sample

# %%
# Instantiate SpaCy's English module - Train Sample
nlp = spacy.load('en_core_web_sm')
# Remove default stop words and lemmatize each sentence
cleanPosts_tr['clean_message'] = cleanPosts_tr.message.apply(
    lambda text: 
        " ".join(
            token.lemma_.lower() for token in nlp(text)
                if token.lemma_.lower() not in nlp.Defaults.stop_words and token.is_alpha
        )
)
# Drop old sentences
cleanPosts_tr.drop(columns='message', inplace=True)

# %% [markdown]
# Test Sample

# %%
# Instantiate SpaCy's English module - Test Sample
nlp = spacy.load('en_core_web_sm')
# Remove default stop words and lemmatize each sentence
cleanPosts_ts['clean_message'] = cleanPosts_ts.message.apply(
    lambda text: 
        " ".join(
            token.lemma_.lower() for token in nlp(text)
                if token.lemma_.lower() not in nlp.Defaults.stop_words and token.is_alpha
        )
)
# Drop old sentences
cleanPosts_ts.drop(columns='message', inplace=True)

# %% [markdown]
# #### Drop rows with empty strings

# %% [markdown]
# Train Sample

# %%
# Drop rows where 'clean_message' is an empty string - Train Sample
# Get index
idx = cleanPosts_tr[cleanPosts_tr['clean_message'] == ''].index
# Drop rows based on index
cleanPosts_tr.drop(index=idx, inplace=True)

# Export to csv file
#cleanPosts_tr.to_csv('cleanPosts_tr.csv', index=False)

# %% [markdown]
# Test Sample

# %%
# Drop rows where 'clean_message' is an empty string - Train Sample
# Get index
idx = cleanPosts_ts[cleanPosts_ts['clean_message'] == ''].index
# Drop rows based on index
cleanPosts_ts.drop(index=idx, inplace=True)

# Export to csv file
#cleanPosts_ts.to_csv('cleanPosts_ts.csv', index=False)

# %% [markdown]
# #### Plot class distribution

# %%
# Plot the class distribution - Train
plot_tr = cleanPosts_tr.label.value_counts().plot(kind='pie',autopct='%1.2f%%')

# %%
# Plot the class distribution - Test
plot_ts = cleanPosts_ts.label.value_counts().plot(kind='pie',autopct='%1.2f%%')

# %% [markdown]
# #### Combine train and test samples into one pandas DataFrame

# %%
# Combine the train and test samples to use for the BoW vocabulary
cleanPosts_cb = pd.concat([cleanPosts_tr, cleanPosts_ts])

# %% [markdown]
# #### Bag-of-Words Vectors

# %%
# Instantiate Count Vectorizer
vectorizer = CountVectorizer()
# Create the vocabulary
vectorizer.fit(cleanPosts_cb.clean_message.to_list())

# Transform train sample to document-term matrix
X_tr = vectorizer.transform(cleanPosts_tr.clean_message.to_list())
# Create a dataframe from the document-term matrix
X_train_b = pd.DataFrame(X_tr.toarray(),columns=vectorizer.get_feature_names_out())

# Transform test sample to document-term matrix
X_ts = vectorizer.transform(cleanPosts_ts.clean_message.to_list())
# Create a dataframe from the document-term matrix
X_test_b = pd.DataFrame(X_ts.toarray(),columns=vectorizer.get_feature_names_out())

# %% [markdown]
# #### Classify text using the SVM Model

# %% [markdown]
# Train the SVM Model

# %%
# Instatiate SVC
svm = LinearSVC()
# Fit training data
svm.fit(X_train_b, cleanPosts_tr.label)
# Get prediction on test data
pred = svm.predict(X_test_b)

# %% [markdown]
# #### Get Accuracy, F1 Score and Confusion Matrix

# %%
# Print the accuracy
print('Accuracy: '+str(svm.score(X_test_b, cleanPosts_ts.label)))
# Print the F1 Score
print('F1 Score: '+str(f1_score(cleanPosts_ts.label, pred, pos_label='hate')))
# Create confusion matrix
cm = confusion_matrix(cleanPosts_ts.label, pred, labels=svm.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svm.classes_)
disp.plot()
plt.show()

# %% [markdown]
# Using the sampled train and test data returned an accuracy of 0.74, which is lower than the accuracy I got using the whole dataset. However, the F1 Score is much higher, 0.74, and the model does a fair job in correctly classifying both hate and noHate classes. These results are very close to the results from the paper and indicate the importance of having a class balaned dataset when it comes to text classification. For the rest of this research, the balanced train and test datasets will be used.

# %% [markdown]
# #### Classify text using CNN Model

# %% [markdown]
# The Hate Speech Dataset paper provides the link for the code used for the CNN model. The code below was downloaded from https://github.com/dennybritz/cnn-text-classification-tf and https://github.com/lubiluk/cnn-sentence.

# %% [markdown]
# #### Prepare the dataset
# 1) Tokenize the text into number sequences
# 2) Pad sequences to the same length (of the longest sequence)
# 3) One hot encode train and test labels

# %%
# Code from notebook provided in https://github.com/lubiluk/cnn-sentence
# Build the vocabulary
max_document_length = max([len(x.split(" ")) for x in cleanPosts_cb.clean_message.to_list()])
# Tokenizer default filtering seems to be identical to original clean_str
tokenizer = Tokenizer()
# Fit vocabulary using both train and test
tokenizer.fit_on_texts(cleanPosts_cb.clean_message.to_list())

# Convert train to sequences
x_train_cnn = np.array(tokenizer.texts_to_sequences(cleanPosts_tr.clean_message.to_list()), dtype='object')
# Pad examples to the same length
x_train_cnn = keras.preprocessing.sequence.pad_sequences(x_train_cnn,
                                               value=0,
                                               padding='post',
                                               maxlen=max_document_length)

# Convert test to sequences
x_test_cnn = np.array(tokenizer.texts_to_sequences(cleanPosts_ts.clean_message.to_list()), dtype='object')
# Pad examples to the same length
x_test_cnn = keras.preprocessing.sequence.pad_sequences(x_test_cnn,
                                               value=0,
                                               padding='post',
                                               maxlen=max_document_length)

# one hot encode train labels
y_train_cnn = pd.get_dummies(cleanPosts_tr.label).astype('int32').values

# one hot encode test labels
y_test_cnn = pd.get_dummies(cleanPosts_ts.label).astype('int32').values

# %% [markdown]
# #### Set up hyperparameters

# %%
# Percentage of the training data to use for validation
dev_sample_percentage = 0.1
# Dimensionality of character embedding (default: 128)
embedding_dim = 128
# Filter sizes (default: [3, 4, 5])
filter_sizes = [3, 4, 5]
# Number of filters per filter size (default: 128)
num_filters = 128
# L2 regularization lambda (default: 0.0) (unused)
l2_reg_lambda = 0.0
# Dropout keep probability (default: 0.5)
dropout_keep_prob = 0.5
# Batch Size (default: 64)
batch_size = 32
# Number of training epochs (default: 200)
num_epochs = 50

# %%
x_train_cnn.shape

# %% [markdown]
# #### Build the model

# %%
# Build the model
sequence_length = x_train_cnn.shape[1]
num_classes = y_train_cnn.shape[1]
vocab_size = len(tokenizer.word_index) + 1
embedding_size = embedding_dim

print("Sequence Length: {}".format(sequence_length))
print("Number of Classes: {}".format(num_classes))
print("Vocabulary Size: {}".format(vocab_size))
print("Embedding Size: {}".format(embedding_size))

inputs = keras.layers.Input(shape=(sequence_length,))
x = keras.layers.Embedding(vocab_size, embedding_size, input_length=sequence_length,
                          embeddings_initializer='random_uniform')(inputs)
x = keras.layers.Reshape((sequence_length, embedding_size, 1))(x)

filter_layers = []

for s in filter_sizes:
  f = keras.layers.Conv2D(
      num_filters, kernel_size=(s, embedding_size), strides=(1, 1),
      padding='valid', data_format='channels_last', activation='relu',
      use_bias=True, kernel_initializer=keras.initializers.TruncatedNormal(stddev=0.01),
      bias_initializer=keras.initializers.Constant(value=0.1))(x)
  f = keras.layers.MaxPooling2D(pool_size=(sequence_length - s + 1, 1), strides=(1, 1), padding='valid', data_format='channels_last')(f)
  filter_layers.append(f)

# Combine all the pooled features
x = keras.layers.concatenate(filter_layers, axis=1)
x = keras.layers.Reshape((num_filters * len(filter_sizes), ))(x)

# Add dropout
x = keras.layers.Dropout(dropout_keep_prob)(x)

# Final (unnormalized) scores and predictions
predictions = keras.layers.Dense(num_classes, use_bias=True, 
                                 bias_initializer=keras.initializers.Constant(value=0.1),
                                 kernel_initializer=keras.initializers.glorot_uniform(seed=None),
                                 kernel_regularizer=keras.regularizers.l2(l2_reg_lambda), 
                                 bias_regularizer=keras.regularizers.l2(l2_reg_lambda),
                                 activation='softmax')(x)
  
model = keras.Model(inputs=inputs, outputs=predictions)
model.summary()

# %% [markdown]
# #### Visualise the CNN Model

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %% [markdown]
# #### Prepare the training process

# %%
# Specify loss function and optimizer
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

# %% [markdown]
# #### Train the CNN Model

# %%
history = model.fit(x_train_cnn,
                    y_train_cnn,
                    epochs=num_epochs,
                    batch_size=batch_size,
                    validation_split=dev_sample_percentage,
                    verbose=1)
